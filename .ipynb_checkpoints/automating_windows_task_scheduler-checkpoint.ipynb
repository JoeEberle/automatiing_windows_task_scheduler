# %% [markdown]
# ![automating_windows_task_scheduler.png](attachment:59c20563-7ea2-4b70-bee3-6898011d3fb8.png)

# %% [markdown]
# # Automating Windows Task Scheduler
#
# ## Launches windows task scheduler to perform python scripts
#
# The Windows Task Scheduler is a built-in utility in the Windows operating system that allows users to schedule automated tasks to run at specific times or under certain conditions without requiring manual intervention.print(definition)
#
# #### by Joe Eberle started on 05-23-2023 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %%
first_install = False 
if first_install:
    # !pip install schedule
    # !pip install zipp

# %%
import os
import schedule
from datetime import datetime
import pandas as pd 
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import time
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-04-12 at 09:29:45.004104

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'automating_windows_task_scheduler'

# %%
definition = '''
The Windows Task Scheduler is a built-in utility in the Windows operating system that allows users to schedule automated tasks to run at specific times or under certain conditions without requiring manual intervention.print(definition)
'''
talking_code = False
if talking_code:
    tc.print_say(definition)
else: 
    print(definition)
# Out:
# The Windows Task Scheduler is a built-in utility in the Windows operating system that allows users to schedule automated tasks to run at specific times or under certain conditions without requiring manual intervention.print(definition)

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process automating_windows_task_scheduler Step 0 - Initializing and starting Logging Process.

# %% [markdown]
# ## step 1 - Define the task scheduler

# %% [markdown]
# step 2 - Launch the task scheduler Step

# %% [markdown]
# step 3 jump for joy

# %% [markdown]
# ## step 26 -  jump for joy

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-04-12 09:29:45,049 - INFO - START automating_windows_task_scheduler =============================================
# 2024-04-12 09:29:45,049 - INFO - START automating_windows_task_scheduler Start Time = 2024-04-12 09:29:45
# 2024-04-12 09:29:45,049 - INFO - automating_windows_task_scheduler Step 0 - Initialize the configuration file parser
# 2024-04-12 09:29:45,049 - INFO - Process automating_windows_task_scheduler Step 0 - Initializing and starting Logging Process.
# 2024-04-12 09:29:45,064 - INFO - PERFORMANCE automating_windows_task_scheduler The total process duration was:0.02
# 2024-04-12 09:29:45,064 - INFO - PERFORMANCE automating_windows_task_scheduler Stop Time = 2024-04-12 09:29:45
# 2024-04-12 09:29:45,064 - INFO - PERFORMANCE automating_windows_task_scheduler Short process duration less than 3 Seconds:0.02
# 2024-04-12 09:29:45,065 - INFO - PERFORMANCE automating_windows_task_scheduler Performance optimization is not reccomended
# ...

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
